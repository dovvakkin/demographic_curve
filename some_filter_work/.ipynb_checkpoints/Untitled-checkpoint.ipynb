# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

from pylab import rcParams
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

rcParams['figure.figsize'] = 16, 5

# %%
data = pd.read_csv("table.csv").T[-15:-5]

# %%
data.tail(10)
# Out:
#            0        1            2         3            4    5       6    \
# 2008  0.532114  17.6894  6.09856e+07  0.284233  9.14742e+06  NaN  101.34
# 2009  0.514913  17.2683  5.79353e+07  0.284233  9.14742e+06  NaN  105.96
# 2010  0.504063  17.0459  5.74830e+07  0.284233  9.14742e+06  NaN  105.92
# 2011  0.486674  16.5806  5.66678e+07  0.284233  9.14742e+06  NaN  101.81
# 2012  0.493984  16.9564  6.02533e+07  0.284233  9.14742e+06  NaN  100.78
# 2013   0.48142  16.6431  5.94868e+07  0.284233  9.14742e+06  NaN  108.95
# 2014  0.484164  16.8644   5.7979e+07  0.284233  9.14742e+06  NaN  114.95
# 2015  0.474279  16.6454    5.812e+07  0.284233  9.14742e+06  NaN  114.12
# 2016       NaN      NaN  5.84541e+07       NaN  9.14742e+06  NaN  122.19
# 2017       NaN      NaN          NaN       NaN  9.14742e+06  NaN     NaN
#
#          7       8            9       ...           116          117      118  \
# 2008  107.59   106.8  9.83151e+06     ...       23.4868  2.16949e+12  6.50615
# ...

# %%
ind = data['Indicator Name']

# %%
# не перезапускать, тут имена колонок!!!
k = 0
for i in ind:
    print("{0} {1}".format(k, i))
    k+=1
# Out:
# 0 Arable land (hectares per person)
# 1 Arable land (% of land area)
# 2 Land under cereal production (hectares)
# 3 Permanent cropland (% of land area)
# 4 Land area (sq. km)
# 5 Agricultural machinery, tractors per 100 sq. km of arable land
# 6 Crop production index (2004-2006 = 100)
# 7 Food production index (2004-2006 = 100)
# 8 Livestock production index (2004-2006 = 100)
# 9 Surface area (sq. km)
# 10 Cereal yield (kg per hectare)
# 11 Rural population (% of total population)
# 12 Rural population
# 13 Mortality rate, under-5 (per 1,000 live births)
# 14 Charges for the use of intellectual property, payments (BoP, current US$)
# 15 Current account balance (BoP, current US$)
# 16 Charges for the use of intellectual property, receipts (BoP, current US$)
# 17 Foreign direct investment, net inflows (BoP, current US$)
# 18 Personal remittances, received (current US$)
# 19 Total reserves (includes gold, current US$)
# 20 Inflation, consumer prices (annual %)
# ...

# %%
# 68 Adolescent fertility rate (births per 1,000 women ages 15-19)
# 71 Fertility rate, total (births per woman)
# 75 Adolescent fertility rate (births per 1,000 women ages 15-19)
# 76 Birth rate, crude (per 1,000 people)
# 82 Fertility rate, total (births per woman)
# 110 Adolescent fertility rate (births per 1,000 women ages 15-19)
y = data[76]
x = data.drop(columns=[68, 71, 75, 76, 82, 110])

# %%
x.tail(10)
# Out:
#            0        1            2         3            4    5       6    \
# 2008  0.532114  17.6894  6.09856e+07  0.284233  9.14742e+06  NaN  101.34
# 2009  0.514913  17.2683  5.79353e+07  0.284233  9.14742e+06  NaN  105.96
# 2010  0.504063  17.0459  5.74830e+07  0.284233  9.14742e+06  NaN  105.92
# 2011  0.486674  16.5806  5.66678e+07  0.284233  9.14742e+06  NaN  101.81
# 2012  0.493984  16.9564  6.02533e+07  0.284233  9.14742e+06  NaN  100.78
# 2013   0.48142  16.6431  5.94868e+07  0.284233  9.14742e+06  NaN  108.95
# 2014  0.484164  16.8644   5.7979e+07  0.284233  9.14742e+06  NaN  114.95
# 2015  0.474279  16.6454    5.812e+07  0.284233  9.14742e+06  NaN  114.12
# 2016       NaN      NaN  5.84541e+07       NaN  9.14742e+06  NaN  122.19
# 2017       NaN      NaN          NaN       NaN  9.14742e+06  NaN     NaN
#
#          7       8            9       ...           116          117      118  \
# 2008  107.59   106.8  9.83151e+06     ...       23.4868  2.16949e+12  6.50615
# ...
